# %% [markdown]
# <a href="https://colab.research.google.com/github/taisizidoro/Python-/blob/master/projeto_1_Bethe_Bloch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Interacão da radiação com a matéria através da equação de Bethe-Bloch**
# # **Grupo: Leon Luis Silva de Abreu, Raphael Gomes de Souza, Tais Dias Izidoro**
#
# O projeto consiste em calcular a distribuiçao diferencial da energia de um múon passando pelo cobre e integrar aequacao para obter a perda total de energia porionizacao.Inicialmente ser ́a explorada a relacao entre $\beta^3$, $\gamma^4$ e $\beta \gamma$, onde as partıculas carregadas irão variar de fracamente relativísticas ($\beta= 0,1$) a ultra-relativísticas ($\gamma= 100$).  Em seguida, a equação de Bethe-Bloch ser ́a construída um pedaço de cada vez.
#
# $-\frac{dE}{dx} = K z^2 \rho \frac{Z}{A} \frac{1}{\beta^2}[ln (\frac{2 m_e c^2 \beta^2 \gamma^2}{I}) - \beta^2 ] $

# %% [markdown]
# (1) Escreva uma função em Python chamada de f_gamma(beta):que tenha como argumento  β  e retorna  γ . Teste-o para um valor de  β , como por exemplo, 0,6. Certifique-se de que sua função gama(beta) possa aceitar um vetor de  β  e retornar um vetor compatível de  γ .

# %%
import math

def beta(v):
  c = 300000000
  return v/c

def gamma(entry, e_type='beta'):
  gamma = []

  if e_type == 'beta':
    for i in range(len(entry)):
      beta = entry[i]  
      gamma.append(1/(math.sqrt(1-beta**2)))

  elif e_type == 'velocidade':
    for i in range(len(entry)):
      beta = beta_fucntion(entry[i]) 
      gamma.append(1/math.sqrt(1 - beta**2))

  else:
    raise ValueError("Entry must be 'beta' or 'velocidade'.")   
  return gamma

#testando 

a = [0.6,0.7]
gamma(a)
# Out:
# [1.25, 1.4002800840280099]

# %% [markdown]
# A partir de um vetor de valores $\beta$ variando de 0 a 0,995, faça um gráfico $\gamma \times \beta$.

# %%
import numpy as np
import matplotlib.pyplot as plt

def gamma_vs_beta(x0,xf,dx):
  x = np.arange( x0, xf, dx)
  a = gamma(x)
  plt.plot( x, a, label='gamma')
  plt.xlabel("beta")
  plt.ylabel("gamma")
  plt.legend()

gamma_vs_beta(0,0.995,0.0001)

# %% [markdown]
# Faça um gráfico $\gamma \beta \times \beta $.  O que você observa?

# %%
def gammabeta_vs_beta(x0,xf,dx):
  Beta = np.arange(x0, xf, dx)
  Gamma = gamma(Beta)
  GammaBeta = [a*b for a,b in zip(Gamma,Beta)]
  plt.plot(Beta, GammaBeta, label='gamma')
  plt.xlabel("beta")
  plt.ylabel(" gamma beta ")
  plt.legend()
  plt.semilogy()

gammabeta_vs_beta(0,0.995,0.001)

# %% [markdown]
# Trace o argumento do log natural na equacao de Bethe-Block em  uma função de $\gamma \beta$. Faça o argumento ser uma nova função lnargument(). Para você: essa função deve aceitar $\beta$ ou $\gamma$ como um argumento, ou ambos, ou seu produto?
# Observe que pode ser muito difícil obter $\beta$ com uma boa precisão a partirem baixas velocidades; o oposto é difícil em velocidades muito altas. Faça o gráfico para um intervalo de 0,1 a 100.
#
#
# $-\frac{dE}{dx} = K z^2 \rho \frac{Z}{A} \frac{1}{\beta^2}[ln (\frac{2 m_e c^2 \beta^2 \gamma^2}{I}) - \beta^2 ] $

# %%
def lnargument(betagamma, I):
  mec2 = 0.5110     #massa do elétron 
  a = 2* mec2*(betagamma)**2
  y = a/I 
  return y


def ln_vs_gammabeta(x0, xf, dx, I):
  BetaGamma = np.arange(x0, xf, dx)
  Argument = lnargument(BetaGamma, I)
  plt.plot(BetaGamma, Argument, label='Energia média de excitação %s' % I )
  plt.xlabel("gamma beta")
  plt.ylabel("ln argument")
  plt.legend()

#O valor de I= 3.22 10^-6 MeV ( Mean excitation energy) usado foi retirado na página PDG do cobre

ln_vs_gammabeta(0.1, 100, 0.01,0.000322)

# %% [markdown]
# Esse gráfico não mostra a região de interesse para valores baixos de $\beta$. Faça o plot com uma escala logarítimica no eixo vertical
# Dica: Procure na ajuda do matplotlib afunção semilogy(). Ficou melhor? Talvez ambos os eixos?

# %%
def ln_vs_gammabeta(x0, xf, dx, I):
  BetaGamma = np.arange(x0, xf, dx)
  Argument = lnargument(BetaGamma, I)
  plt.plot(BetaGamma, Argument, label='Energia média de excitação %s' % I )
  plt.xlabel("gamma beta")
  plt.ylabel("ln argument")
  plt.legend()
  plt.semilogy()
  plt.semilogx()

#O valor de I= 3.22 10^-6 MeV ( Mean excitation energy) usado foi retirado na página PDG do cobre

ln_vs_gammabeta(0.1, 100, 0.01, 0.000322)

# %% [markdown]
# Provável que agora, seus valores $\gamma \beta$ não estão  uniformemente espaçados no gráfico. Faça um vetor de valores $\gamma \beta$ que tenham um logaritmo uniformemente espaçado de 0,1 a 100. Repita o gráfico mais uma vez usando os novos argumentos. Uma identidade útil aqui é $\gamma^2= (\gamma \beta)^2+ 1$

# %%
def ln_vs_gammabeta(x0, xf, dx, I):
  BetaGamma = np.arange(x0, xf, dx)
  Argument = lnargument(BetaGamma, I)
  plt.plot( np.log(BetaGamma), Argument, label='Energia média de excitação %s' % I )
  plt.xlabel("gamma beta")
  plt.ylabel("ln argument")
  plt.legend()
  plt.semilogy()

#O valor de I= 3.22 10^-6 MeV ( Mean excitation energy) usado foi retirado na página PDG do cobre

ln_vs_gammabeta(0.1, 100, 0.01, 0.000322)

# %% [markdown]
# Plote o "conteúdo dos colchetes $\times \gamma\beta$ usando o mesmo espaçamento do vetor de log para o argumento x. Para termos números reais de I, escolha múons que penetram em um absorvedor de cobre. Esse é um número adimensional que pode variar de 3,55 a maisde 16.
#
# $[ln (\frac{2 m_e c^2 \beta^2 \gamma^2}{I}) - \beta^2 ]$

# %%
def betagamma_gamma(betagamma):
  gamma = (betagamma**2 + 1)**(1/2)
  return gamma

def gamma_beta(gamma): #usando a identidade dada
  beta =  ((gamma**2 -1)**(1/2))/gamma
  return beta

def betagamma_beta(betagamma):
  gamma = betagamma_gamma(betagamma)  
  beta = gamma_beta(gamma)
  return beta

def colchetes(betagamma, I): 
  Argument = lnargument(betagamma, I)  
  lnArgument = np.log(Argument) 
  beta = betagamma_beta(betagamma)
  y = lnArgument - beta**2
  return y

def colchetes_vs_gammabeta(x0, xf, dx, I):
  BetaGamma = np.arange( x0, xf, dx)
  Colchetes = colchetes(BetaGamma, I)
  plt.plot(BetaGamma, Colchetes, label='Energia média de excitação %s' % I )
  plt.xlabel("gamma beta")
  plt.ylabel("Colchetes argument")
  plt.legend()
  plt.semilogx()
  plt.semilogy()

#O valor de I= 3.22 10^-6 MeV ( Mean excitation energy) usado foi retirado na página PDG do cobre

colchetes_vs_gammabeta(0.001, 10000, 0.01, 0.000322)

# %% [markdown]
# Finalmente, plote toda a equação **-(dE/dx)**, a energia perdida por unidade de distância para múons que passam pelo cobre. Os dados que você precisa sobre o cobre estão todos no PDG. Além disso, pode encontrar mais sobre o múons aqui.Convertendo para nossas unidades, a perda de energia deve ter uma largura mínima de 13 MeV/cm para o momento do múon ou energia de 300 Mev.
# $-\frac{dE}{dx}= Kz^2d\frac{Z}{A}\frac{1}{\beta^2}[ln (\frac{2 m_e c^2 \beta^2 \gamma^2}{I}) - \beta^2 ]$

# %%
def lost_energy(betagamma, I):
  K = 0.307         #MeV [cm2mol−1]
  z = 1             # Carga da Partícula incididente - adimensional (e)
  rho = 8.960       # Densidade do meio - [gcm-3]
  Z = 29            # N ́umero atômico do meio - adimensional (e)
  A = 63.546        # N ́umero de massa do meio - [gmol-1]
  Colchetes = colchetes( betagamma, I)
  beta = betagamma_beta(betagamma)
  dEdx = K*(z**2)*rho*(Z/A)*(beta**(-2))*Colchetes
  return dEdx

def LostEnergy(x0, xf, dx, I):
  BetaGamma = np.arange(x0, xf, dx)
  Lost_Energy = lost_energy(BetaGamma, I)
  plt.plot(BetaGamma, Lost_Energy, label= 'Energia média de excitação %s' % I)
  plt.xlabel("gamma beta")
  plt.ylabel("dE/dx")
  plt.legend()
  plt.semilogy()
  plt.semilogx() 

#testando para I=10 

LostEnergy(0.1, 100000, 0.01, 0.000322)
